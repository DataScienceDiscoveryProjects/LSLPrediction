# %% [markdown]
# https://rapidapi.com/s.mahmoud97/api/zillow56
#
# I've signed up with this service for a free plan which allows 30 API calls a month. They did not ask for my credit card.
#
# Please test it out to see if this would work for our purpose. If yes, we will try to secure fund to buy a paid plan.

# %%
import http.client

conn = http.client.HTTPSConnection("zillow56.p.rapidapi.com")

headers = {
    'X-RapidAPI-Key': "7a19687cdfmshbcf34fbdd6d1f3bp16b9b2jsna3aeadf4281a",
    'X-RapidAPI-Host': "zillow56.p.rapidapi.com"
}

conn.request("GET", "/search_address?address=17%20Carriage%20Dr%20Irvine%20CA%2092602", headers=headers)

res = conn.getresponse()
data = res.read()

print(data.decode("utf-8"))
# Out:
# {
#   "abbreviatedAddress": "17 Carriage Dr",
#   "address": {
#     "city": "Irvine",
#     "community": null,
#     "neighborhood": null,
#     "state": "CA",
#     "streetAddress": "17 Carriage Dr",
#     "subdivision": null,
#     "zipcode": "92602"
#   },
#   "apartmentsForRentInZipcodeSearchUrl": {
#     "path": "/irvine-ca-92602/apartments/"
#   },
#   "attributionInfo": {
#     "agentEmail": null,
#     "agentLicenseNumber": null,
#     "agentName": null,
#     "agentPhoneNumber": null,
#     "attributionTitle": null,
#     "brokerName": null,
#     "brokerPhoneNumber": null,
#     "buyerAgentMemberStateLicense": null,
#     "buyerAgentName": null,
#     "buyerBrokerageName": null,
#     "coAgentLicenseNumber": null,
#     "coAgentName": null,
#     "coAgentNumber": null,
#     "infoList1": [
#       {
#         "infoField1": "listOffice",
#         "infoField2": null
#       }
#     ],
#     "infoList2": [],
#     "infoString1": null,
#     "infoString10": null,
#     "infoString11": null,
#     "infoString12": null,
#     "infoString13": null,
#     "infoString14": null,
#     "infoString15": null,
#     "infoString16": null,
#     "infoString17": null,
#     "infoString18": null,
#     "infoString19": null,
#     "infoString2": null,
#     "infoString20": null,
#     "infoString3": null,
#     "infoString4": null,
#     "infoString5": null,
#     "infoString6": null,
#     "infoString7": null,
#     "infoString9": null,
#     "lastChecked": null,
#     "lastUpdated": null,
#     "listingAgents": [],
#     "listingAgreement": null,
#     "listingOffices": [
#       {
#         "associatedOfficeType": "listOffice",
#         "officeName": null
#       }
#     ],
#     "mlsDisclaimer": null,
#     "mlsId": null,
#     "mlsName": null,
#     "providerLogo": null,
#     "trueStatus": null
#   },
#   "bathrooms": 3,
#   "bedrooms": 4,
#   "big": [
#     {
#       "subjectType": null,
#       "url": "https://maps.googleapis.com/maps/api/streetview?location=17+Carriage+Dr%2C+Irvine%2C+CA+92602&size=550x413&key=AIzaSyARFMLB1na-BBWf7_R3-5YOQQaHqEJf6RQ&source=outdoor&&signature=X8M6tKHioA5Sq9AZgJZWRPlxTG4=",
#       "width": 550
#     }
#   ],
#   "boroughId": null,
#   "boroughSearchUrl": null,
#   "brokerId": null,
#   "brokerIdDimension": "Unknown Listed By",
#   "brokerageName": null,
#   "building": null,
#   "buildingId": null,
#   "city": "Irvine",
#   "cityId": 52650,
#   "citySearchUrl": {
#     "path": "/irvine-ca/",
#     "text": "Homes in Irvine"
#   },
#   "comingSoonOnMarketDate": null,
#   "communityUrl": null,
#   "comps": [],
#   "contingentListingType": null,
#   "country": "USA",
#   "county": "Orange County",
#   "countyFIPS": "06059",
#   "countyId": 1286,
#   "currency": "USD",
#   "datePostedString": "",
#   "datePriceChanged": null,
#   "dateSold": 1301529600000,
#   "dateSoldString": "2011-03-31",
#   "daysOnZillow": 4559,
#   "description": "This beautiful Fieldstone home, tucked nicely away at the end of a long driveway, has a really functional floorplan with a big living room, a great family room with built-in bookcases that opens directly into the kitchen with center island, and a private, peaceful backyard. Upstairs bedrooms are roomy, and the vast master bedroom has a bathroom with double sinks, separate tub & shower, and a HUGE walk-in closet. One of the upstairs bedrooms has a giant alcove perfect as a retreat or home office. Even the walk-in pantry located off the kitchen is really big! Located in an award-winning school district, and with NO association dues, this happy home will be the site of many great neighborhood parties for years to come!",
#   "desktopWebHdpImageLink": "https://maps.googleapis.com/maps/api/streetview?location=17+Carriage+Dr%2C+Irvine%2C+CA+92602&size=550x413&key=AIzaSyARFMLB1na-BBWf7_R3-5YOQQaHqEJf6RQ&source=outdoor&&signature=X8M6tKHioA5Sq9AZgJZWRPlxTG4=",
#   "downPaymentAssistance": null,
#   "editPropertyHistorylink": null,
#   "enhancedBrokerImageUrl": null,
#   "favoriteCount": 0,
#   "featuredListingTypeDimension": "organic",
#   "floorMaps": [],
#   "foreclosingBank": null,
#   "foreclosureAmount": null,
#   "foreclosureAuctionCity": null,
#   "foreclosureAuctionDescription": null,
#   "foreclosureAuctionFilingDate": null,
#   "foreclosureAuctionLocation": null,
#   "foreclosureAuctionTime": null,
#   "foreclosureBalanceReportingDate": null,
#   "foreclosureDate": null,
#   "foreclosureDefaultFilingDate": null,
#   "foreclosureJudicialType": "Non-Judicial",
#   "foreclosureLoanAmount": null,
#   "foreclosureLoanDate": null,
#   "foreclosureLoanOriginator": null,
#   "foreclosureMoreInfo": null,
#   "foreclosurePastDueBalance": null,
#   "foreclosurePriorSaleAmount": null,
#   "foreclosurePriorSaleDate": null,
#   "foreclosureTypes": {
#     "isAnyForeclosure": false,
#     "isBankOwned": false,
#     "isForeclosedNFS": false,
#     "isPreforeclosure": false,
#     "wasDefault": null,
#     "wasForeclosed": false,
#     "wasNonRetailAuction": false,
#     "wasREO": null
#   },
#   "foreclosureUnpaidBalance": null,
#   "formattedChip": {
#     "location": [
#       {
#         "fullValue": "17 Carriage Dr"
#       },
#       {
#         "fullValue": "Irvine, CA 92602"
#       }
#     ]
#   },
#   "hasApprovedThirdPartyVirtualTourUrl": false,
#   "hasBadGeocode": false,
#   "hasPublicVideo": false,
#   "hasVRModel": null,
#   "hdpTypeDimension": "Zestimate",
#   "hdpUrl": "/homedetails/17-Carriage-Dr-Irvine-CA-92602/25521141_zpid/",
#   "hiResImageLink": "https://maps.googleapis.com/maps/api/streetview?location=17+Carriage+Dr%2C+Irvine%2C+CA+92602&size=1025x768&key=AIzaSyARFMLB1na-BBWf7_R3-5YOQQaHqEJf6RQ&source=outdoor&&signature=1FtaKHWidEsHjVNLCfaDXGwzJRM=",
#   "hideZMA": false,
#   "hideZestimate": false,
#   "homeInsights": null,
#   "homeRecommendations": {
#     "blendedRecs": [],
#     "displayShort": ""
#   },
#   "homeStatus": "OTHER",
#   "homeType": "SINGLE_FAMILY",
#   "homeValues": null,
#   "housesForRentInZipcodeSearchUrl": {
#     "path": "/irvine-ca-92602/rent-houses/"
#   },
#   "hugePhotos": [
#     {
#       "caption": "",
#       "height": 768,
#       "url": "https://maps.googleapis.com/maps/api/streetview?location=17+Carriage+Dr%2C+Irvine%2C+CA+92602&size=1025x768&key=AIzaSyARFMLB1na-BBWf7_R3-5YOQQaHqEJf6RQ&source=outdoor&&signature=1FtaKHWidEsHjVNLCfaDXGwzJRM=",
#       "width": 1025
#     }
#   ],
#   "isCamo": null,
#   "isCommunityPillar": null,
#   "isCurrentSignedInAgentResponsible": false,
#   "isCurrentSignedInUserVerifiedOwner": false,
#   "isFeatured": false,
#   "isIncomeRestricted": null,
#   "isListedByOwner": false,
#   "isListingClaimedByCurrentSignedInUser": false,
#   "isNonOwnerOccupied": false,
#   "isPaidMultiFamilyBrokerId": false,
#   "isPreforeclosureAuction": false,
#   "isPremierBuilder": false,
#   "isRecentStatusChange": false,
#   "isRentalListingOffMarket": false,
#   "isRentalsLeadCapMet": false,
#   "isUndisclosedAddress": false,
#   "isZillowOwned": false,
#   "keystoneHomeStatus": "NotForSale",
#   "lastSoldPrice": 650000,
#   "latitude": 33.742397,
#   "listPriceLow": null,
#   "listingAccountUserId": null,
#   "listingDataSource": "Legacy",
#   "listingFeedID": null,
#   "listingMetadata": {
#     "FlexibleLayoutAA": true,
#     "FlexibleLayoutAB": true,
#     "FlexibleLayoutB": true,
#     "FlexibleLayoutC": true,
#     "FlexibleLayoutD": true,
#     "FlexibleLayoutE": true,
#     "FlexibleLayoutF": false,
#     "FlexibleLayoutG": false,
#     "FlexibleLayoutH": true,
#     "FlexibleLayoutI": true,
#     "FlexibleLayoutJ": false,
#     "FlexibleLayoutK": false,
#     "FlexibleLayoutL": false,
#     "FlexibleLayoutM": true,
#     "FlexibleLayoutN": true,
#     "FlexibleLayoutO": true,
#     "FlexibleLayoutP": false,
#     "FlexibleLayoutQ": false,
#     "FlexibleLayoutR": false,
#     "FlexibleLayoutS": false,
#     "FlexibleLayoutT": false,
#     "FlexibleLayoutU": false,
#     "FlexibleLayoutV": false,
#     "FlexibleLayoutW": false,
#     "FlexibleLayoutX": false,
#     "FlexibleLayoutY": false,
#     "FlexibleLayoutZ": false,
#     "canCommingleComparables": true,
#     "canShowAutomatedValuationDisplay": true,
#     "canShowComparables": true,
#     "canShowCroppedPhotos": true,
#     "canShowNonIDXMedia": true,
#     "canShowOnMap": true,
#     "canShowPrequalifiedLinkInChip": true,
#     "canShowPriceHistory": true,
#     "canShowTaxHistory": true,
#     "canShowUserGeneratedContent": true,
#     "canShowZillowLogoInHeader": true,
#     "comminglingCategory": true,
#     "comminglingCategoryIsRulesApplicable": false,
#     "hidePriceAdjustmentFlexField": false,
#     "isAdsRestricted": false,
#     "isSuperTrafficOptimized": false,
#     "mustAttributeOfficeNameBeforeAgentName": false,
#     "mustDisplayAttributionListAgentEmail": false,
#     "mustDisplayAttributionListAgentPhone": false,
#     "mustDisplayAttributionListingOfficePhone": false,
#     "mustDisplayDisclaimerBelowAttribution": false,
#     "mustDisplayFeedLogoInContactBox": false,
#     "mustHighlightAgentName": null,
#     "mustHighlightListOfficeName": false,
#     "mustHighlightMarketingType": false,
#     "mustHighlightMlsId": null,
#     "mustHighlightMlsStatus": false,
#     "mustMakeListingAgentContactable": false,
#     "passwordRequiredForZestimateMarketAnalysis": false
#   },
#   "listingProvider": {
#     "agentLicenseNumber": null,
#     "agentName": null,
#     "disclaimerText": null,
#     "enhancedDescriptionText": null,
#     "enhancedVideoURL": null,
#     "isZRMSourceText": null,
#     "logos": [],
#     "postingGroupName": null,
#     "postingWebsiteLinkText": "See listing website",
#     "postingWebsiteURL": null,
#     "showLogos": null,
#     "showNoContactInfoMessage": false,
#     "sourceText": null,
#     "title": "Listing Provided by"
#   },
#   "listingSubType": {
#     "isBankOwned": false,
#     "isComingSoon": false,
#     "isFSBA": false,
#     "isFSBO": false,
#     "isForAuction": false,
#     "isForeclosure": false,
#     "isNewHome": false,
#     "isOpenHouse": false,
#     "isPending": false
#   },
#   "listingTypeDimension": "Unknown Listed By",
#   "listing_agent": null,
#   "listing_sub_type": {
#     "is_FSBA": false,
#     "is_FSBO": false,
#     "is_bankOwned": false,
#     "is_comingSoon": false,
#     "is_forAuction": false,
#     "is_foreclosure": false,
#     "is_newHome": false,
#     "is_openHouse": false,
#     "is_pending": false
#   },
#   "livingArea": 2250,
#   "livingAreaUnits": "Square Feet",
#   "livingAreaUnitsShort": "sqft",
#   "livingAreaValue": 2250,
#   "longitude": -117.77203,
#   "lotAreaUnits": "Square Feet",
#   "lotAreaValue": 4912,
#   "lotSize": 4912,
#   "mapTileGoogleMapUrlFullWidthLightbox": "https://maps.googleapis.com/maps/api/staticmap?center=33.742397,-117.77203&zoom=16&size=1024x234&maptype=roadmap&key=AIzaSyARFMLB1na-BBWf7_R3-5YOQQaHqEJf6RQ&scale=2&signature=5reLbTzq7ISqkuH7zshYlB77SgM=",
#   "mapTileGoogleMapUrlFullWidthLightboxWholeZipcode": "https://maps.googleapis.com/maps/api/staticmap?center=33.742397,-117.77203&zoom=12&size=1024x234&maptype=roadmap&key=AIzaSyARFMLB1na-BBWf7_R3-5YOQQaHqEJf6RQ&scale=2&signature=88WQO8BDEqFH1huVx7HG5k0sKnU=",
#   "mapTileGoogleMapUrlFullWidthMax": "https://maps.googleapis.com/maps/api/staticmap?center=33.742397,-117.77203&zoom=16&size=1920x234&maptype=roadmap&key=AIzaSyARFMLB1na-BBWf7_R3-5YOQQaHqEJf6RQ&signature=JpFqyMgw8a1XJda2k_9N9cAo9dE=",
#   "mapTileGoogleMapUrlFullWidthMaxWholeZipcode": "https://maps.googleapis.com/maps/api/staticmap?center=33.742397,-117.77203&zoom=12&size=1920x234&maptype=roadmap&key=AIzaSyARFMLB1na-BBWf7_R3-5YOQQaHqEJf6RQ&signature=eiSX3TwlHmjwleEga6fUhUMqbE0=",
#   "mapTileGoogleMapUrlSmall": "https://maps.googleapis.com/maps/api/staticmap?center=33.742397,-117.77203&zoom=14&size=280x208&maptype=roadmap&key=AIzaSyARFMLB1na-BBWf7_R3-5YOQQaHqEJf6RQ&scale=2&signature=tomLVYTSSZkJcbV3NyTi0KcenSo=",
#   "mapTileGoogleMapUrlSmallWholeZipcode": "https://maps.googleapis.com/maps/api/staticmap?center=33.742397,-117.77203&zoom=12&size=280x208&maptype=roadmap&key=AIzaSyARFMLB1na-BBWf7_R3-5YOQQaHqEJf6RQ&scale=2&signature=OWfEI5waG-aFN24kEyniB520_VA=",
#   "marketingName": null,
#   "mediumImageLink": "https://maps.googleapis.com/maps/api/streetview?location=17+Carriage+Dr%2C+Irvine%2C+CA+92602&size=400x300&key=AIzaSyARFMLB1na-BBWf7_R3-5YOQQaHqEJf6RQ&source=outdoor&&signature=tln-ZFQAw23e8tGUMKxqvs1rj4Y=",
#   "mlsid": null,
#   "monthlyHoaFee": null,
#   "mortgageRates": {
#     "arm5Rate": 7.22,
#     "fifteenYearFixedRate": 7.245,
#     "thirtyYearFixedRate": 7.217
#   },
#   "moveHomeMapLocationLink": null,
#   "moveInCompletionDate": null,
#   "moveInReady": false,
#   "nearbyCities": [
#     {
#       "body": null,
#       "name": "Anaheim",
#       "regionUrl": {
#         "path": "/anaheim-ca/"
#       }
#     },
#     {
#       "body": null,
#       "name": "Costa Mesa",
#       "regionUrl": {
#         "path": "/costa-mesa-ca/"
#       }
#     },
#     {
#       "body": null,
#       "name": "Fullerton",
#       "regionUrl": {
#         "path": "/fullerton-ca/"
#       }
#     },
#     {
#       "body": null,
#       "name": "Garden Grove",
#       "regionUrl": {
#         "path": "/garden-grove-ca/"
#       }
#     },
#     {
#       "body": null,
#       "name": "Huntington Beach",
#       "regionUrl": {
#         "path": "/huntington-beach-ca/"
#       }
#     },
#     {
#       "body": null,
#       "name": "Irvine",
#       "regionUrl": {
#         "path": "/irvine-ca/"
#       }
#     },
#     {
#       "body": null,
#       "name": "Mission Viejo",
#       "regionUrl": {
#         "path": "/mission-viejo-ca/"
#       }
#     },
#     {
#       "body": null,
#       "name": "Orange",
#       "regionUrl": {
#         "path": "/orange-ca/"
#       }
#     },
#     {
#       "body": null,
#       "name": "Santa Ana",
#       "regionUrl": {
#         "path": "/santa-ana-ca/"
#       }
#     },
#     {
#       "body": null,
#       "name": "Westminster",
#       "regionUrl": {
#         "path": "/westminster-ca/"
#       }
#     }
#   ],
#   "nearbyHomes": [
#     {
#       "address": {
#         "city": "Irvine",
#         "state": "CA",
#         "streetAddress": "15 Carriage Dr",
#         "zipcode": "92602"
#       },
#       "attributionInfo": {
#         "agentName": null,
#         "agentPhoneNumber": null,
#         "brokerName": null,
#         "brokerPhoneNumber": null,
#         "mlsId": null,
#         "mlsName": null,
#         "providerLogo": null,
#         "trueStatus": null
#       },
#       "bathrooms": 2.5,
#       "bedrooms": 3,
#       "currency": "USD",
#       "hdpUrl": "/homedetails/15-Carriage-Dr-Irvine-CA-92602/25521142_zpid/",
#       "homeStatus": "OTHER",
#       "homeType": "SINGLE_FAMILY",
#       "isPremierBuilder": false,
#       "isZillowOwned": false,
#       "latitude": 33.74233,
#       "listing_sub_type": {
#         "is_FSBA": false,
#         "is_FSBO": false,
#         "is_bankOwned": false,
#         "is_comingSoon": false,
#         "is_forAuction": false,
#         "is_foreclosure": false,
#         "is_newHome": false
#       },
#       "livingArea": 2246,
#       "livingAreaUnits": "Square Feet",
#       "livingAreaUnitsShort": "sqft",
#       "livingAreaValue": 2246,
#       "longitude": -117.771904,
#       "lotAreaUnits": "Square Feet",
#       "lotAreaValue": 3901,
#       "lotSize": 3901,
#       "miniCardPhotos": [
#         {
#           "url": "https://maps.googleapis.com/maps/api/streetview?location=15+Carriage+Dr%2C+Irvine%2C+CA+92602&size=316x234&key=AIzaSyARFMLB1na-BBWf7_R3-5YOQQaHqEJf6RQ&source=outdoor&&signature=Aj9bwrfckw_aV9jNIgFFZSEZ6FU="
#         }
#       ],
#       "newConstructionType": null,
#       "price": 1554800,
#       "providerListingID": null,
#       "state": "CA",
#       "zpid": 25521142
#     },
#     {
#       "address": {
#         "city": "Irvine",
#         "state": "CA",
#         "streetAddress": "19 Carriage Dr",
#         "zipcode": "92602"
#       },
#       "attributionInfo": {
#         "agentName": null,
#         "agentPhoneNumber": null,
#         "brokerName": null,
#         "brokerPhoneNumber": null,
#         "mlsId": null,
#         "mlsName": null,
#         "providerLogo": null,
#         "trueStatus": null
#       },
#       "bathrooms": 3,
#       "bedrooms": 4,
#       "currency": "USD",
#       "hdpUrl": "/homedetails/19-Carriage-Dr-Irvine-CA-92602/25521140_zpid/",
#       "homeStatus": "OTHER",
#       "homeType": "SINGLE_FAMILY",
#       "isPremierBuilder": false,
#       "isZillowOwned": false,
#       "latitude": 33.742466,
#       "listing_sub_type": {
#         "is_FSBA": false,
#         "is_FSBO": false,
#         "is_bankOwned": false,
#         "is_comingSoon": false,
#         "is_forAuction": false,
#         "is_foreclosure": false,
#         "is_newHome": false
#       },
#       "livingArea": 2478,
#       "livingAreaUnits": "Square Feet",
#       "livingAreaUnitsShort": "sqft",
#       "livingAreaValue": 2478,
#       "longitude": -117.77218,
#       "lotAreaUnits": "Square Feet",
#       "lotAreaValue": 6734,
#       "lotSize": 6734,
#       "miniCardPhotos": [
#         {
#           "url": "https://maps.googleapis.com/maps/api/streetview?location=19+Carriage+Dr%2C+Irvine%2C+CA+92602&size=316x234&key=AIzaSyARFMLB1na-BBWf7_R3-5YOQQaHqEJf6RQ&source=outdoor&&signature=RgNtWxtWOxqam6qfBqpZir8J_vs="
#         }
#       ],
#       "newConstructionType": null,
#       "price": 1795000,
#       "providerListingID": null,
#       "state": "CA",
#       "zpid": 25521140
#     },
#     {
#       "address": {
#         "city": "Irvine",
#         "state": "CA",
#         "streetAddress": "11 Carriage Dr",
#         "zipcode": "92602"
#       },
#       "attributionInfo": {
#         "agentName": null,
#         "agentPhoneNumber": null,
#         "brokerName": null,
#         "brokerPhoneNumber": null,
#         "mlsId": null,
#         "mlsName": null,
#         "providerLogo": null,
#         "trueStatus": null
#       },
#       "bathrooms": 2.5,
#       "bedrooms": 4,
#       "currency": "USD",
#       "hdpUrl": "/homedetails/11-Carriage-Dr-Irvine-CA-92602/25521143_zpid/",
#       "homeStatus": "OTHER",
#       "homeType": "SINGLE_FAMILY",
#       "isPremierBuilder": false,
#       "isZillowOwned": false,
#       "latitude": 33.74225,
#       "listing_sub_type": {
#         "is_FSBA": false,
#         "is_FSBO": false,
#         "is_bankOwned": false,
#         "is_comingSoon": false,
#         "is_forAuction": false,
#         "is_foreclosure": false,
#         "is_newHome": false
#       },
#       "livingArea": 2480,
#       "livingAreaUnits": "Square Feet",
#       "livingAreaUnitsShort": "sqft",
#       "livingAreaValue": 2480,
#       "longitude": -117.77179,
#       "lotAreaUnits": "Square Feet",
#       "lotAreaValue": 3916,
#       "lotSize": 3916,
#       "miniCardPhotos": [
#         {
#           "url": "https://photos.zillowstatic.com/fp/5000c42c8ee3c49dc74fc77c55eadf22-p_c.jpg"
#         }
#       ],
#       "newConstructionType": null,
#       "price": 1608500,
#       "providerListingID": null,
#       "state": "CA",
#       "zpid": 25521143
#     },
#     {
#       "address": {
#         "city": "Irvine",
#         "state": "CA",
#         "streetAddress": "21 Carriage Dr",
#         "zipcode": "92602"
#       },
#       "attributionInfo": {
#         "agentName": null,
#         "agentPhoneNumber": null,
#         "brokerName": null,
#         "brokerPhoneNumber": null,
#         "mlsId": null,
#         "mlsName": null,
#         "providerLogo": null,
#         "trueStatus": null
#       },
#       "bathrooms": 3,
#       "bedrooms": 4,
#       "currency": "USD",
#       "hdpUrl": "/homedetails/21-Carriage-Dr-Irvine-CA-92602/25521139_zpid/",
#       "homeStatus": "OTHER",
#       "homeType": "SINGLE_FAMILY",
#       "isPremierBuilder": false,
#       "isZillowOwned": false,
#       "latitude": 33.74233,
#       "listing_sub_type": {
#         "is_FSBA": false,
#         "is_FSBO": false,
#         "is_bankOwned": false,
#         "is_comingSoon": false,
#         "is_forAuction": false,
#         "is_foreclosure": false,
#         "is_newHome": false
#       },
#       "livingArea": 2250,
#       "livingAreaUnits": "Square Feet",
#       "livingAreaUnitsShort": "sqft",
#       "livingAreaValue": 2250,
#       "longitude": -117.77233,
#       "lotAreaUnits": "Square Feet",
#       "lotAreaValue": 3936,
#       "lotSize": 3936,
#       "miniCardPhotos": [
#         {
#           "url": "https://maps.googleapis.com/maps/api/streetview?location=21+Carriage+Dr%2C+Irvine%2C+CA+92602&size=316x234&key=AIzaSyARFMLB1na-BBWf7_R3-5YOQQaHqEJf6RQ&source=outdoor&&signature=TA9RDW09uNMfR6atitYbkQc2lUc="
#         }
#       ],
#       "newConstructionType": null,
#       "price": 1554900,
#       "providerListingID": null,
#       "state": "CA",
#       "zpid": 25521139
#     },
#     {
#       "address": {
#         "city": "Irvine",
#         "state": "CA",
#         "streetAddress": "76 Linhaven",
#         "zipcode": "92602"
#       },
#       "attributionInfo": {
#         "agentName": null,
#         "agentPhoneNumber": null,
#         "brokerName": null,
#         "brokerPhoneNumber": null,
#         "mlsId": null,
#         "mlsName": null,
#         "providerLogo": null,
#         "trueStatus": null
#       },
#       "bathrooms": 2.5,
#       "bedrooms": 4,
#       "currency": "USD",
#       "hdpUrl": "/homedetails/76-Linhaven-Irvine-CA-92602/25521157_zpid/",
#       "homeStatus": "OTHER",
#       "homeType": "SINGLE_FAMILY",
#       "isPremierBuilder": false,
#       "isZillowOwned": false,
#       "latitude": 33.74259,
#       "listing_sub_type": {
#         "is_FSBA": false,
#         "is_FSBO": false,
#         "is_bankOwned": false,
#         "is_comingSoon": false,
#         "is_forAuction": false,
#         "is_foreclosure": false,
#         "is_newHome": false
#       },
#       "livingArea": 2200,
#       "livingAreaUnits": "Square Feet",
#       "livingAreaUnitsShort": "sqft",
#       "livingAreaValue": 2200,
#       "longitude": -117.77181,
#       "lotAreaUnits": "Square Feet",
#       "lotAreaValue": 5009,
#       "lotSize": 5009,
#       "miniCardPhotos": [
#         {
#           "url": "https://photos.zillowstatic.com/fp/3adc243a50e2c93f84a2d703b3118b58-p_c.jpg"
#         }
#       ],
#       "newConstructionType": null,
#       "price": 1605800,
#       "providerListingID": null,
#       "state": "CA",
#       "zpid": 25521157
#     },
#     {
#       "address": {
#         "city": "Irvine",
#         "state": "CA",
#         "streetAddress": "78 Linhaven",
#         "zipcode": "92602"
#       },
#       "attributionInfo": {
#         "agentName": null,
#         "agentPhoneNumber": null,
#         "brokerName": null,
#         "brokerPhoneNumber": null,
#         "mlsId": null,
#         "mlsName": null,
#         "providerLogo": null,
#         "trueStatus": null
#       },
#       "bathrooms": 2.5,
#       "bedrooms": 4,
#       "currency": "USD",
#       "hdpUrl": "/homedetails/78-Linhaven-Irvine-CA-92602/25521156_zpid/",
#       "homeStatus": "OTHER",
#       "homeType": "SINGLE_FAMILY",
#       "isPremierBuilder": false,
#       "isZillowOwned": false,
#       "latitude": 33.742496,
#       "listing_sub_type": {
#         "is_FSBA": false,
#         "is_FSBO": false,
#         "is_bankOwned": false,
#         "is_comingSoon": false,
#         "is_forAuction": false,
#         "is_foreclosure": false,
#         "is_newHome": false
#       },
#       "livingArea": 2121,
#       "livingAreaUnits": "Square Feet",
#       "livingAreaUnitsShort": "sqft",
#       "livingAreaValue": 2121,
#       "longitude": -117.77171,
#       "lotAreaUnits": "Square Feet",
#       "lotAreaValue": 3571,
#       "lotSize": 3571,
#       "miniCardPhotos": [
#         {
#           "url": "https://maps.googleapis.com/maps/api/streetview?location=78+Linhaven%2C+Irvine%2C+CA+92602&size=316x234&key=AIzaSyARFMLB1na-BBWf7_R3-5YOQQaHqEJf6RQ&source=outdoor&&signature=IkapHEslYn0i1Pnhll1h4JUj7B0="
#         }
#       ],
#       "newConstructionType": null,
#       "price": 1512700,
#       "providerListingID": null,
#       "state": "CA",
#       "zpid": 25521156
#     },
#     {
#       "address": {
#         "city": "Irvine",
#         "state": "CA",
#         "streetAddress": "74 Linhaven",
#         "zipcode": "92602"
#       },
#       "attributionInfo": {
#         "agentName": null,
#         "agentPhoneNumber": null,
#         "brokerName": null,
#         "brokerPhoneNumber": null,
#         "mlsId": null,
#         "mlsName": null,
#         "providerLogo": null,
#         "trueStatus": null
#       },
#       "bathrooms": 3,
#       "bedrooms": 4,
#       "currency": "USD",
#       "hdpUrl": "/homedetails/74-Linhaven-Irvine-CA-92602/25521158_zpid/",
#       "homeStatus": "OTHER",
#       "homeType": "SINGLE_FAMILY",
#       "isPremierBuilder": false,
#       "isZillowOwned": false,
#       "latitude": 33.742702,
#       "listing_sub_type": {
#         "is_FSBA": false,
#         "is_FSBO": false,
#         "is_bankOwned": false,
#         "is_comingSoon": false,
#         "is_forAuction": false,
#         "is_foreclosure": false,
#         "is_newHome": false
#       },
#       "livingArea": 2500,
#       "livingAreaUnits": "Square Feet",
#       "livingAreaUnitsShort": "sqft",
#       "livingAreaValue": 2500,
#       "longitude": -117.77191,
#       "lotAreaUnits": "Square Feet",
#       "lotAreaValue": 7013,
#       "lotSize": 7013,
#       "miniCardPhotos": [
#         {
#           "url": "https://photos.zillowstatic.com/fp/dfadf857960e8b5e711ac59751082ec5-p_c.jpg"
#         }
#       ],
#       "newConstructionType": null,
#       "price": 1822200,
#       "providerListingID": null,
#       "state": "CA",
#       "zpid": 25521158
#     },
#     {
#       "address": {
#         "city": "Irvine",
#         "state": "CA",
#         "streetAddress": "22 Carriage Dr",
#         "zipcode": "92602"
#       },
#       "attributionInfo": {
#         "agentName": null,
#         "agentPhoneNumber": null,
#         "brokerName": null,
#         "brokerPhoneNumber": null,
#         "mlsId": null,
#         "mlsName": null,
#         "providerLogo": null,
#         "trueStatus": null
#       },
#       "bathrooms": 2.5,
#       "bedrooms": 3,
#       "currency": "USD",
#       "hdpUrl": "/homedetails/22-Carriage-Dr-Irvine-CA-92602/25521180_zpid/",
#       "homeStatus": "OTHER",
#       "homeType": "SINGLE_FAMILY",
#       "isPremierBuilder": false,
#       "isZillowOwned": false,
#       "latitude": 33.74203,
#       "listing_sub_type": {
#         "is_FSBA": false,
#         "is_FSBO": false,
#         "is_bankOwned": false,
#         "is_comingSoon": false,
#         "is_forAuction": false,
#         "is_foreclosure": false,
#         "is_newHome": false
#       },
#       "livingArea": 2480,
#       "livingAreaUnits": "Square Feet",
#       "livingAreaUnitsShort": "sqft",
#       "livingAreaValue": 2480,
#       "longitude": -117.77209,
#       "lotAreaUnits": "Square Feet",
#       "lotAreaValue": 4596,
#       "lotSize": 4596,
#       "miniCardPhotos": [
#         {
#           "url": "https://maps.googleapis.com/maps/api/streetview?location=22+Carriage+Dr%2C+Irvine%2C+CA+92602&size=316x234&key=AIzaSyARFMLB1na-BBWf7_R3-5YOQQaHqEJf6RQ&source=outdoor&&signature=BExzumMSSVansP9r7PNlbtc-Dhc="
#         }
#       ],
#       "newConstructionType": null,
#       "price": 1679100,
#       "providerListingID": null,
#       "state": "CA",
#       "zpid": 25521180
#     }
#   ],
#   "nearbyNeighborhoods": [
#     {
#       "body": null,
#       "name": "Business District",
#       "regionUrl": {
#         "path": "/business-district-irvine-ca/"
#       }
#     },
#     {
#       "body": null,
#       "name": "Cypress Village",
#       "regionUrl": {
#         "path": "/cypress-village-irvine-ca/"
#       }
#     },
#     {
#       "body": null,
#       "name": "El Camino Real",
#       "regionUrl": {
#         "path": "/el-camino-real-irvine-ca/"
#       }
#     },
#     {
#       "body": null,
#       "name": "Lower Peters Canyon",
#       "regionUrl": {
#         "path": "/lower-peters-canyon-irvine-ca/"
#       }
#     },
#     {
#       "body": null,
#       "name": "Northwood",
#       "regionUrl": {
#         "path": "/northwood-irvine-ca/"
#       }
#     },
#     {
#       "body": null,
#       "name": "Orange County Great Park",
#       "regionUrl": {
#         "path": "/orange-county-great-park-irvine-ca/"
#       }
#     },
#     {
#       "body": null,
#       "name": "UC Irvine",
#       "regionUrl": {
#         "path": "/uc-irvine-irvine-ca/"
#       }
#     },
#     {
#       "body": null,
#       "name": "West Park",
#       "regionUrl": {
#         "path": "/west-park-irvine-ca/"
#       }
#     },
#     {
#       "body": null,
#       "name": "Woodbridge",
#       "regionUrl": {
#         "path": "/woodbridge-irvine-ca/"
#       }
#     },
#     {
#       "body": null,
#       "name": "Woodbury",
#       "regionUrl": {
#         "path": "/woodbury-irvine-ca/"
#       }
#     }
#   ],
#   "nearbyZipcodes": [
#     {
#       "body": null,
#       "name": "92602",
#       "regionUrl": {
#         "path": "/irvine-ca-92602/"
#       }
#     },
#     {
#       "body": null,
#       "name": "92603",
#       "regionUrl": {
#         "path": "/irvine-ca-92603/"
#       }
#     },
#     {
#       "body": null,
#       "name": "92604",
#       "regionUrl": {
#         "path": "/irvine-ca-92604/"
#       }
#     },
#     {
#       "body": null,
#       "name": "92606",
#       "regionUrl": {
#         "path": "/irvine-ca-92606/"
#       }
#     },
#     {
#       "body": null,
#       "name": "92612",
#       "regionUrl": {
#         "path": "/irvine-ca-92612/"
#       }
#     },
#     {
#       "body": null,
#       "name": "92614",
#       "regionUrl": {
#         "path": "/irvine-ca-92614/"
#       }
#     },
#     {
#       "body": null,
#       "name": "92617",
#       "regionUrl": {
#         "path": "/irvine-ca-92617/"
#       }
#     },
#     {
#       "body": null,
#       "name": "92618",
#       "regionUrl": {
#         "path": "/irvine-ca-92618/"
#       }
#     },
#     {
#       "body": null,
#       "name": "92620",
#       "regionUrl": {
#         "path": "/irvine-ca-92620/"
#       }
#     },
#     {
#       "body": null,
#       "name": "92697",
#       "regionUrl": {
#         "path": "/irvine-ca-92697/"
#       }
#     }
#   ],
#   "neighborhoodRegion": {
#     "name": "West Irvine"
#   },
#   "neighborhoodSearchUrl": {
#     "path": "/west-irvine-irvine-ca/"
#   },
#   "newConstructionType": null,
#   "onsiteMessage": {
#     "decisionContext": {},
#     "eventId": "d85ef4db-426d-487d-8dae-efa692d3d02f",
#     "messages": [
#       {
#         "bucket": "BASELINE_TREATMENT",
#         "decisionContext": {
#           "city": "Irvine",
#           "countyId": "1286",
#           "guid": "e91c8bf3-1da5-4530-9ca9-409c5af78f16",
#           "hasUserClaimedHome": false,
#           "homeStatus": "zestimate",
#           "homeType": "SINGLE_FAMILY",
#           "isAdsRestricted": false,
#           "isZillowOwned": false,
#           "leadType": "",
#           "leadTypes": [],
#           "listPrice": 1542100,
#           "operatingSystem": "windows",
#           "placementId": "wow-top",
#           "shouldDisplayUpsell": false,
#           "state": "CA",
#           "stateId": "9",
#           "streetAddress": "17 Carriage Dr",
#           "surfaceId": "fshdp",
#           "zestimate": "1542100",
#           "zipcode": "92602",
#           "zoMarketCode": "NO_MARKET"
#         },
#         "eventId": "dca4d395-33e6-4997-9d15-a85c0f1a1be8",
#         "isGlobalHoldout": false,
#         "lastModified": "1687877355",
#         "passThrottle": true,
#         "placementId": 399,
#         "placementName": "HDPTopSlot",
#         "qualifiedTreatments": [
#           {
#             "id": 5292,
#             "lastModified": "1692801206",
#             "name": "mortgages-zhl_fshdp_top_purchase_zhl-pre-qual-corner-copy",
#             "status": "BASELINE_EVALUATION"
#           },
#           {
#             "id": 2239,
#             "lastModified": "1668425760",
#             "name": "ZGM_Purchase_FSHDP_Pre_Qual",
#             "status": "PORTFOLIO"
#           },
#           {
#             "id": 5294,
#             "lastModified": "1692801222",
#             "name": "mortgages-zhl_fshdp_top_purchase_zhl-pre-qual-corner-logo",
#             "status": "BASELINE_EVALUATION"
#           },
#           {
#             "id": 5299,
#             "lastModified": "1692801250",
#             "name": "mortgages-zhl_fshdp_top_purchase_zhl-pre-qual-afford-corner-logo",
#             "status": "BASELINE_EVALUATION"
#           },
#           {
#             "id": 4273,
#             "lastModified": "1687965607",
#             "name": "mortgages-zhl_purchase_fshdp_top_pre-qual-affordabilty-hybrid-zhl-corner",
#             "status": "PORTFOLIO"
#           },
#           {
#             "id": 5297,
#             "lastModified": "1692801242",
#             "name": "mortgages-zhl_fshdp_top_purchase_zhl-pre-qual-afford-corner-copy",
#             "status": "BASELINE_EVALUATION"
#           },
#           {
#             "id": 4269,
#             "lastModified": "1687965706",
#             "name": "mortgages-zhl_purchase_fshdp_top_pre-qual-zhl-corner",
#             "status": "PORTFOLIO"
#           }
#         ],
#         "selectedTreatment": {
#           "component": "UpsellWrapper",
#           "id": 5297,
#           "lastModified": "1692801242",
#           "name": "mortgages-zhl_fshdp_top_purchase_zhl-pre-qual-afford-corner-copy",
#           "renderingProps": "{\"actionLink\":\"https://www.zillowhomeloans.com/pre-qualify/?source=Zillow&channel=FSHDP&utm_source=OMP&utm_medium=OMP&utm_campaign=mortgages-zhl_fshdp_top_purchase_zhl-pre-qual-afford-corner-copy&propertyValue=1542100&propertyType=SingleFamilyHome&cityOrZip=92602&zuid=&guid=e91c8bf3-1da5-4530-9ca9-409c5af78f16\",\"actionText\":\"Start now\",\"actionType\":\"url_link\",\"background\":\"backgroundBlue\",\"bodyMarkdownText\":\"At Zillow Home Loans, we can pre-qualify you in as little as 3 minutes.  <p class=\\\"zg-mls-note\\\">An equal housing lender. NMLS #10287.</p><style> div[class*=Upsell-] .zg-mls-note{ font-size: 10px; font-weight: 400; position: absolute; right: 4px; bottom: 0; margin-bottom: -4px; color: grey; } </style>\",\"headingMarkdownText\":\"Wondering how much you can afford?\",\"icon\":\"houseWithDollarSign\",\"overrideMargin\":\"16px\",\"hasBorder\":false,\"showAdvertisement\":true,\"tagInput\":\"Zillow Home Loans\",\"gaImpressionCategory\":\"Homes\",\"gaImpressionAction\":\"ZHL Purchase Upsell\",\"gaImpressionLabel\":\"Display|fshdp|top|zhl-purchase|zhl-pre-qual-afford-corner-copy|omp\",\"gaEngagementCategory\":\"Homes\",\"gaEngagementAction\":\"ZHL Purchase Upsell\",\"gaEngagementLabel\":\"Click|fshdp|top|zhl-purchase|zhl-pre-qual-afford-corner-copy|omp\",\"gaHoverCategory\":\"Homes\",\"gaHoverAction\":\"ZHL Purchase Upsell\",\"gaHoverLabel\":\"Hover|fshdp|top|zhl-purchase|zhl-pre-qual-afford-corner-copy|omp\"}",
#           "status": "BASELINE_EVALUATION"
#         },
#         "shouldDisplay": true,
#         "skipDisplayReason": null,
#         "testPhase": "BASELINE"
#       }
#     ]
#   },
#   "openHouseSchedule": [],
#   "pageUrlFragment": "Zestimate",
#   "pageViewCount": 5,
#   "pals": [],
#   "parcelId": "53053118",
#   "parentRegion": {
#     "name": "West Irvine"
#   },
#   "photoCount": 1,
#   "photos": [
#     {
#       "caption": "",
#       "mixedSources": {
#         "jpeg": [
#           {
#             "url": "https://maps.googleapis.com/maps/api/streetview?location=17+Carriage+Dr%2C+Irvine%2C+CA+92602&size=192x144&key=AIzaSyARFMLB1na-BBWf7_R3-5YOQQaHqEJf6RQ&source=outdoor&&signature=wV36pMk22wtBfGFANJNQPSOCtLM=",
#             "width": 192
#           },
#           {
#             "url": "https://maps.googleapis.com/maps/api/streetview?location=17+Carriage+Dr%2C+Irvine%2C+CA+92602&size=384x288&key=AIzaSyARFMLB1na-BBWf7_R3-5YOQQaHqEJf6RQ&source=outdoor&&signature=YI6Kr5KdFbjxIcdfG8peXBPXdHc=",
#             "width": 384
#           },
#           {
#             "url": "https://maps.googleapis.com/maps/api/streetview?location=17+Carriage+Dr%2C+Irvine%2C+CA+92602&size=576x432&key=AIzaSyARFMLB1na-BBWf7_R3-5YOQQaHqEJf6RQ&source=outdoor&&signature=v8WQLupJgxKFg6OZF8sTHiJhSOc=",
#             "width": 576
#           },
#           {
#             "url": "https://maps.googleapis.com/maps/api/streetview?location=17+Carriage+Dr%2C+Irvine%2C+CA+92602&size=768x576&key=AIzaSyARFMLB1na-BBWf7_R3-5YOQQaHqEJf6RQ&source=outdoor&&signature=zoRVFOqaH_Mzrs3o2ZJ_TiopuQ4=",
#             "width": 768
#           },
#           {
#             "url": "https://maps.googleapis.com/maps/api/streetview?location=17+Carriage+Dr%2C+Irvine%2C+CA+92602&size=960x720&key=AIzaSyARFMLB1na-BBWf7_R3-5YOQQaHqEJf6RQ&source=outdoor&&signature=F8wKtUd3y0B89II2mh0WAtM2F1Q=",
#             "width": 960
#           },
#           {
#             "url": "https://maps.googleapis.com/maps/api/streetview?location=17+Carriage+Dr%2C+Irvine%2C+CA+92602&size=1152x864&key=AIzaSyARFMLB1na-BBWf7_R3-5YOQQaHqEJf6RQ&source=outdoor&&signature=LU_qS0I3Rk3MdRe7hT4tiViQ6pM=",
#             "width": 1152
#           },
#           {
#             "url": "https://maps.googleapis.com/maps/api/streetview?location=17+Carriage+Dr%2C+Irvine%2C+CA+92602&size=1344x1008&key=AIzaSyARFMLB1na-BBWf7_R3-5YOQQaHqEJf6RQ&source=outdoor&&signature=GPo73s4FFefmu3symppVwFfwmKM=",
#             "width": 1344
#           },
#           {
#             "url": "https://maps.googleapis.com/maps/api/streetview?location=17+Carriage+Dr%2C+Irvine%2C+CA+92602&size=1536x1152&key=AIzaSyARFMLB1na-BBWf7_R3-5YOQQaHqEJf6RQ&source=outdoor&&signature=iwaFhrxbWpyDYMt7pLII38HrkG0=",
#             "width": 1536
#           }
#         ],
#         "webp": [
#           {
#             "url": "https://maps.googleapis.com/maps/api/streetview?location=17+Carriage+Dr%2C+Irvine%2C+CA+92602&size=192x144&key=AIzaSyARFMLB1na-BBWf7_R3-5YOQQaHqEJf6RQ&source=outdoor&&signature=wV36pMk22wtBfGFANJNQPSOCtLM=",
#             "width": 192
#           },
#           {
#             "url": "https://maps.googleapis.com/maps/api/streetview?location=17+Carriage+Dr%2C+Irvine%2C+CA+92602&size=384x288&key=AIzaSyARFMLB1na-BBWf7_R3-5YOQQaHqEJf6RQ&source=outdoor&&signature=YI6Kr5KdFbjxIcdfG8peXBPXdHc=",
#             "width": 384
#           },
#           {
#             "url": "https://maps.googleapis.com/maps/api/streetview?location=17+Carriage+Dr%2C+Irvine%2C+CA+92602&size=576x432&key=AIzaSyARFMLB1na-BBWf7_R3-5YOQQaHqEJf6RQ&source=outdoor&&signature=v8WQLupJgxKFg6OZF8sTHiJhSOc=",
#             "width": 576
#           },
#           {
#             "url": "https://maps.googleapis.com/maps/api/streetview?location=17+Carriage+Dr%2C+Irvine%2C+CA+92602&size=768x576&key=AIzaSyARFMLB1na-BBWf7_R3-5YOQQaHqEJf6RQ&source=outdoor&&signature=zoRVFOqaH_Mzrs3o2ZJ_TiopuQ4=",
#             "width": 768
#           },
#           {
#             "url": "https://maps.googleapis.com/maps/api/streetview?location=17+Carriage+Dr%2C+Irvine%2C+CA+92602&size=960x720&key=AIzaSyARFMLB1na-BBWf7_R3-5YOQQaHqEJf6RQ&source=outdoor&&signature=F8wKtUd3y0B89II2mh0WAtM2F1Q=",
#             "width": 960
#           },
#           {
#             "url": "https://maps.googleapis.com/maps/api/streetview?location=17+Carriage+Dr%2C+Irvine%2C+CA+92602&size=1152x864&key=AIzaSyARFMLB1na-BBWf7_R3-5YOQQaHqEJf6RQ&source=outdoor&&signature=LU_qS0I3Rk3MdRe7hT4tiViQ6pM=",
#             "width": 1152
#           },
#           {
#             "url": "https://maps.googleapis.com/maps/api/streetview?location=17+Carriage+Dr%2C+Irvine%2C+CA+92602&size=1344x1008&key=AIzaSyARFMLB1na-BBWf7_R3-5YOQQaHqEJf6RQ&source=outdoor&&signature=GPo73s4FFefmu3symppVwFfwmKM=",
#             "width": 1344
#           },
#           {
#             "url": "https://maps.googleapis.com/maps/api/streetview?location=17+Carriage+Dr%2C+Irvine%2C+CA+92602&size=1536x1152&key=AIzaSyARFMLB1na-BBWf7_R3-5YOQQaHqEJf6RQ&source=outdoor&&signature=iwaFhrxbWpyDYMt7pLII38HrkG0=",
#             "width": 1536
#           }
#         ]
#       }
#     }
#   ],
#   "postingContact": {
#     "name": null,
#     "photo": null
#   },
#   "postingProductType": "Standard",
#   "postingUrl": null,
#   "price": 1542100,
#   "priceChange": null,
#   "priceChangeDate": null,
#   "priceChangeDateString": null,
#   "priceHistory": [
#     {
#       "attributeSource": {
#         "infoString1": null,
#         "infoString2": "Public Record",
#         "infoString3": null
#       },
#       "buyerAgent": null,
#       "date": "2011-03-31",
#       "event": "Sold",
#       "postingIsRental": false,
#       "price": 650000,
#       "priceChangeRate": -0.015151515151515152,
#       "pricePerSquareFoot": 289,
#       "sellerAgent": null,
#       "showCountyLink": false,
#       "source": "Public Record",
#       "time": 1301529600000
#     },
#     {
#       "attributeSource": {
#         "infoString1": "P727630",
#         "infoString2": "First Team Real Estate",
#         "infoString3": null
#       },
#       "buyerAgent": null,
#       "date": "2010-09-10",
#       "event": "Price change",
#       "postingIsRental": false,
#       "price": 660000,
#       "priceChangeRate": -0.022222222222222223,
#       "pricePerSquareFoot": 293,
#       "sellerAgent": null,
#       "showCountyLink": false,
#       "source": "First Team Real Estate",
#       "time": 1284076800000
#     },
#     {
#       "attributeSource": {
#         "infoString1": "P727630",
#         "infoString2": "First Team Real Estate",
#         "infoString3": null
#       },
#       "buyerAgent": null,
#       "date": "2010-08-18",
#       "event": "Price change",
#       "postingIsRental": false,
#       "price": 675000,
#       "priceChangeRate": -0.034334763948497854,
#       "pricePerSquareFoot": 300,
#       "sellerAgent": null,
#       "showCountyLink": false,
#       "source": "First Team Real Estate",
#       "time": 1282089600000
#     },
#     {
#       "attributeSource": {
#         "infoString1": "P727630",
#         "infoString2": "First Team Real Estate",
#         "infoString3": null
#       },
#       "buyerAgent": null,
#       "date": "2010-08-03",
#       "event": "Price change",
#       "postingIsRental": false,
#       "price": 699000,
#       "priceChangeRate": -0.022377622377622378,
#       "pricePerSquareFoot": 311,
#       "sellerAgent": null,
#       "showCountyLink": false,
#       "source": "First Team Real Estate",
#       "time": 1280793600000
#     },
#     {
#       "attributeSource": {
#         "infoString1": "P727630",
#         "infoString2": "First Team Real Estate",
#         "infoString3": null
#       },
#       "buyerAgent": null,
#       "date": "2010-07-25",
#       "event": "Price change",
#       "postingIsRental": false,
#       "price": 715000,
#       "priceChangeRate": -0.040268456375838924,
#       "pricePerSquareFoot": 318,
#       "sellerAgent": null,
#       "showCountyLink": false,
#       "source": "First Team Real Estate",
#       "time": 1280016000000
#     },
#     {
#       "attributeSource": {
#         "infoString1": "P727630",
#         "infoString2": "First Team Real Estate",
#         "infoString3": null
#       },
#       "buyerAgent": null,
#       "date": "2010-04-04",
#       "event": "Price change",
#       "postingIsRental": false,
#       "price": 745000,
#       "priceChangeRate": 0.04195804195804196,
#       "pricePerSquareFoot": 331,
#       "sellerAgent": null,
#       "showCountyLink": false,
#       "source": "First Team Real Estate",
#       "time": 1270339200000
#     },
#     {
#       "attributeSource": {
#         "infoString1": "P727630",
#         "infoString2": "First Team Real Estate",
#         "infoString3": null
#       },
#       "buyerAgent": null,
#       "date": "2010-03-27",
#       "event": "Listed for sale",
#       "postingIsRental": false,
#       "price": 715000,
#       "priceChangeRate": 1.0516499282639886,
#       "pricePerSquareFoot": 318,
#       "sellerAgent": null,
#       "showCountyLink": false,
#       "source": "First Team Real Estate",
#       "time": 1269648000000
#     },
#     {
#       "attributeSource": {
#         "infoString1": null,
#         "infoString2": "Public Record",
#         "infoString3": null
#       },
#       "buyerAgent": null,
#       "date": "1999-07-30",
#       "event": "Sold",
#       "postingIsRental": false,
#       "price": 348500,
#       "priceChangeRate": 0,
#       "pricePerSquareFoot": 155,
#       "sellerAgent": null,
#       "showCountyLink": false,
#       "source": "Public Record",
#       "time": 933292800000
#     }
#   ],
#   "primaryPublicVideo": null,
#   "propertyEventLogLink": null,
#   "propertyTaxRate": 1.07,
#   "propertyTypeDimension": "Single Family",
#   "propertyUpdatePageLink": null,
#   "providerListingID": null,
#   "regionString": "Irvine CA 92602",
#   "rentZestimate": 4982,
#   "rentalApplicationsAcceptedType": "REQUEST_TO_APPLY",
#   "resoFacts": {
#     "aboveGradeFinishedArea": null,
#     "accessibilityFeatures": null,
#     "additionalParcelsDescription": null,
#     "allowedPets": null,
#     "appliances": [],
#     "architecturalStyle": null,
#     "associationAmenities": null,
#     "associationFee": null,
#     "associationFee2": null,
#     "associationFeeIncludes": null,
#     "associationName": null,
#     "associationName2": null,
#     "associationPhone": null,
#     "associationPhone2": null,
#     "atAGlanceFacts": [
#       {
#         "factLabel": "Type",
#         "factValue": "SingleFamily"
#       },
#       {
#         "factLabel": "Year Built",
#         "factValue": "1999"
#       },
#       {
#         "factLabel": "Heating",
#         "factValue": null
#       },
#       {
#         "factLabel": "Cooling",
#         "factValue": null
#       },
#       {
#         "factLabel": "Parking",
#         "factValue": "Garage - Attached"
#       },
#       {
#         "factLabel": "Lot",
#         "factValue": "4,912 sqft"
#       },
#       {
#         "factLabel": "Offer Review Date",
#         "factValue": null
#       }
#     ],
#     "attic": null,
#     "availabilityDate": null,
#     "basement": null,
#     "basementYN": false,
#     "bathrooms": 3,
#     "bathroomsFull": null,
#     "bathroomsHalf": null,
#     "bathroomsOneQuarter": null,
#     "bathroomsPartial": null,
#     "bathroomsThreeQuarter": null,
#     "bedrooms": 4,
#     "belowGradeFinishedArea": null,
#     "bodyType": null,
#     "builderModel": null,
#     "builderName": null,
#     "buildingArea": null,
#     "buildingAreaSource": null,
#     "buildingFeatures": null,
#     "buildingName": null,
#     "buyerAgencyCompensation": null,
#     "buyerAgencyCompensationType": null,
#     "canRaiseHorses": false,
#     "carportSpaces": null,
#     "cityRegion": "Irvine",
#     "commonWalls": null,
#     "communityFeatures": [],
#     "constructionMaterials": [],
#     "cooling": [],
#     "coveredSpaces": null,
#     "cropsIncludedYN": null,
#     "daysOnZillow": 4559,
#     "depositsAndFees": null,
#     "developmentStatus": null,
#     "doorFeatures": null,
#     "electric": null,
#     "elementarySchool": null,
#     "elementarySchoolDistrict": null,
#     "elevation": null,
#     "elevationUnits": null,
#     "entryLevel": null,
#     "entryLocation": null,
#     "exclusions": null,
#     "exteriorFeatures": [],
#     "fencing": null,
#     "fireplaceFeatures": null,
#     "fireplaces": null,
#     "flooring": [],
#     "foundationArea": null,
#     "foundationDetails": [],
#     "frontageLength": null,
#     "frontageType": null,
#     "furnished": false,
#     "garageSpaces": null,
#     "gas": null,
#     "greenBuildingVerificationType": null,
#     "greenEnergyEfficient": null,
#     "greenIndoorAirQuality": null,
#     "greenSustainability": null,
#     "greenWaterConservation": null,
#     "hasAdditionalParcels": false,
#     "hasAssociation": null,
#     "hasAttachedGarage": null,
#     "hasAttachedProperty": false,
#     "hasCarport": null,
#     "hasCooling": false,
#     "hasElectricOnProperty": null,
#     "hasFireplace": null,
#     "hasGarage": false,
#     "hasHeating": false,
#     "hasHomeWarranty": false,
#     "hasLandLease": false,
#     "hasOpenParking": null,
#     "hasPetsAllowed": null,
#     "hasPrivatePool": null,
#     "hasRentControl": null,
#     "hasSpa": false,
#     "hasView": false,
#     "hasWaterfrontView": null,
#     "heating": [],
#     "highSchool": null,
#     "highSchoolDistrict": null,
#     "hoaFee": null,
#     "homeType": "SingleFamily",
#     "horseAmenities": null,
#     "horseYN": null,
#     "inclusions": null,
#     "incomeIncludes": null,
#     "interiorFeatures": null,
#     "irrigationWaterRightsAcres": null,
#     "irrigationWaterRightsYN": null,
#     "isNewConstruction": null,
#     "isSeniorCommunity": null,
#     "landLeaseAmount": null,
#     "landLeaseExpirationDate": null,
#     "laundryFeatures": null,
#     "leaseTerm": null,
#     "levels": null,
#     "listAOR": null,
#     "listingId": null,
#     "listingTerms": null,
#     "livingArea": "2,250 sqft",
#     "livingAreaRange": null,
#     "livingAreaRangeUnits": null,
#     "lotFeatures": null,
#     "lotSize": "4,912 sqft",
#     "lotSizeDimensions": null,
#     "mainLevelBathrooms": null,
#     "mainLevelBedrooms": null,
#     "marketingType": null,
#     "middleOrJuniorSchool": null,
#     "middleOrJuniorSchoolDistrict": null,
#     "municipality": null,
#     "numberOfUnitsInCommunity": null,
#     "numberOfUnitsVacant": null,
#     "offerReviewDate": null,
#     "onMarketDate": null,
#     "openParkingSpaces": null,
#     "otherEquipment": null,
#     "otherFacts": [],
#     "otherParking": null,
#     "otherStructures": null,
#     "ownership": null,
#     "ownershipType": null,
#     "parcelNumber": "53053118",
#     "parking": 0,
#     "parkingFeatures": [
#       "Garage - Attached"
#     ],
#     "patioAndPorchFeatures": null,
#     "petsMaxWeight": null,
#     "poolFeatures": null,
#     "pricePerSquareFoot": 685,
#     "propertyCondition": null,
#     "propertySubType": null,
#     "roadSurfaceType": null,
#     "roofType": null,
#     "rooms": [],
#     "securityFeatures": null,
#     "sewer": null,
#     "spaFeatures": null,
#     "specialListingConditions": null,
#     "stories": null,
#     "storiesTotal": null,
#     "structureType": null,
#     "subdivisionName": null,
#     "taxAnnualAmount": null,
#     "tenantPays": null,
#     "topography": null,
#     "totalActualRent": null,
# ...
#                           "action": "click",
#                           "category": "manage_rentals",
#                           "label": "applications",
#                           "newLaneEvent": {
#                             "clickstream_trigger": {
#                               "trigger_location_nm": "top_navigation",
#                               "trigger_object_nm": "no_trigger_object",
#                               "trigger_source_nm": "top_navigation",
#                               "trigger_type_nm": "interaction"
#                             },
#                             "envelope": {
#                               "event_client_start_dtm": "Sun Sep 24 2023",
#                               "event_template_id": "242",
#                               "event_template_version_id": "1",
#                               "event_type_id": 3781,
#                               "event_type_version_id": "1"
#                             },
#                             "semantic": {
#                               "semantic_event_nm": "top_nav_click"
#                             },
#                             "top_navigation": {
#                               "level_one_txt": "Manage Rentals",
#                               "level_three_txt": "Applications",
#                               "level_two_txt": "Rental Management Tools",
#                               "target_url": "/rental-manager/select-property?type=applications&source=topnav&itc=postbutton_topnav"
#                             }
#                           }
#                         },
#                         "href": "/rental-manager/select-property?type=applications&source=topnav&itc=postbutton_topnav",
#                         "id": "applications",
#                         "text": "Applications"
#                       },
#                       {
#                         "classString": "noroute",
#                         "gaClickEventObj": {
#                           "action": "click",
#                           "category": "manage_rentals",
#                           "label": "leases",
#                           "newLaneEvent": {
#                             "clickstream_trigger": {
#                               "trigger_location_nm": "top_navigation",
#                               "trigger_object_nm": "no_trigger_object",
#                               "trigger_source_nm": "top_navigation",
#                               "trigger_type_nm": "interaction"
#                             },
#                             "envelope": {
#                               "event_client_start_dtm": "Sun Sep 24 2023",
#                               "event_template_id": "242",
#                               "event_template_version_id": "1",
#                               "event_type_id": 3781,
#                               "event_type_version_id": "1"
#                             },
#                             "semantic": {
#                               "semantic_event_nm": "top_nav_click"
#                             },
#                             "top_navigation": {
#                               "level_one_txt": "Manage Rentals",
#                               "level_three_txt": "Leases",
#                               "level_two_txt": "Rental Management Tools",
#                               "target_url": "/rental-manager/select-property?type=leases&source=topnav&itc=postbutton_topnav"
#                             }
#                           }
#                         },
#                         "href": "/rental-manager/select-property?type=leases&source=topnav&itc=postbutton_topnav",
#                         "id": "leases",
#                         "text": "Leases"
#                       },
#                       {
#                         "classString": "noroute",
#                         "gaClickEventObj": {
#                           "action": "click",
#                           "category": "manage_rentals",
#                           "label": "payments",
#                           "newLaneEvent": {
#                             "clickstream_trigger": {
#                               "trigger_location_nm": "top_navigation",
#                               "trigger_object_nm": "no_trigger_object",
#                               "trigger_source_nm": "top_navigation",
#                               "trigger_type_nm": "interaction"
#                             },
#                             "envelope": {
#                               "event_client_start_dtm": "Sun Sep 24 2023",
#                               "event_template_id": "242",
#                               "event_template_version_id": "1",
#                               "event_type_id": 3781,
#                               "event_type_version_id": "1"
#                             },
#                             "semantic": {
#                               "semantic_event_nm": "top_nav_click"
#                             },
#                             "top_navigation": {
#                               "level_one_txt": "Manage Rentals",
#                               "level_three_txt": "Payments",
#                               "level_two_txt": "Rental Management Tools",
#                               "target_url": "/rental-manager/select-property?type=payments&source=topnav&itc=postbutton_topnav"
#                             }
#                           }
#                         },
#                         "href": "/rental-manager/select-property?type=payments&source=topnav&itc=postbutton_topnav",
#                         "id": "payments",
#                         "text": "Payments"
#                       }
#                     ]
#                   ],
#                   "title": "Rental Management Tools"
#                 },
#                 {
#                   "links": [
#                     [
#                       {
#                         "classString": "noroute",
#                         "gaClickEventObj": {
#                           "action": "click",
#                           "category": "manage_rentals",
#                           "label": "about",
#                           "newLaneEvent": {
#                             "clickstream_trigger": {
#                               "trigger_location_nm": "top_navigation",
#                               "trigger_object_nm": "no_trigger_object",
#                               "trigger_source_nm": "top_navigation",
#                               "trigger_type_nm": "interaction"
#                             },
#                             "envelope": {
#                               "event_client_start_dtm": "Sun Sep 24 2023",
#                               "event_template_id": "242",
#                               "event_template_version_id": "1",
#                               "event_type_id": 3781,
#                               "event_type_version_id": "1"
#                             },
#                             "semantic": {
#                               "semantic_event_nm": "top_nav_click"
#                             },
#                             "top_navigation": {
#                               "level_one_txt": "Manage Rentals",
#                               "level_three_txt": "Zillow Rental Manager",
#                               "level_two_txt": "Learn More",
#                               "target_url": "/rental-manager/?source=topnav&itc=list_zrm_topnav"
#                             }
#                           }
#                         },
#                         "href": "/rental-manager/?source=topnav&itc=list_zrm_topnav",
#                         "id": "zrm",
#                         "text": "Zillow Rental Manager"
#                       },
#                       {
#                         "classString": "noroute",
#                         "gaClickEventObj": {
#                           "action": "click",
#                           "category": "manage_rentals",
#                           "label": "price",
#                           "newLaneEvent": {
#                             "clickstream_trigger": {
#                               "trigger_location_nm": "top_navigation",
#                               "trigger_object_nm": "no_trigger_object",
#                               "trigger_source_nm": "top_navigation",
#                               "trigger_type_nm": "interaction"
#                             },
#                             "envelope": {
#                               "event_client_start_dtm": "Sun Sep 24 2023",
#                               "event_template_id": "242",
#                               "event_template_version_id": "1",
#                               "event_type_id": 3781,
#                               "event_type_version_id": "1"
#                             },
#                             "semantic": {
#                               "semantic_event_nm": "top_nav_click"
#                             },
#                             "top_navigation": {
#                               "level_one_txt": "Manage Rentals",
#                               "level_three_txt": "Price My Rental",
#                               "level_two_txt": "Learn More",
#                               "target_url": "/rental-manager/price-my-rental/?itc=ltr_zw_ltr_zrm-home_tpnv_price-my-rental"
#                             }
#                           }
#                         },
#                         "href": "/rental-manager/price-my-rental/?itc=ltr_zw_ltr_zrm-home_tpnv_price-my-rental",
#                         "id": "price_my_rental",
#                         "text": "Price My Rental"
#                       },
#                       {
#                         "classString": "noroute",
#                         "gaClickEventObj": {
#                           "action": "click",
#                           "category": "manage_rentals",
#                           "label": "resource",
#                           "newLaneEvent": {
#                             "clickstream_trigger": {
#                               "trigger_location_nm": "top_navigation",
#                               "trigger_object_nm": "no_trigger_object",
#                               "trigger_source_nm": "top_navigation",
#                               "trigger_type_nm": "interaction"
#                             },
#                             "envelope": {
#                               "event_client_start_dtm": "Sun Sep 24 2023",
#                               "event_template_id": "242",
#                               "event_template_version_id": "1",
#                               "event_type_id": 3781,
#                               "event_type_version_id": "1"
#                             },
#                             "semantic": {
#                               "semantic_event_nm": "top_nav_click"
#                             },
#                             "top_navigation": {
#                               "level_one_txt": "Manage Rentals",
#                               "level_three_txt": "Resource Center",
#                               "level_two_txt": "Learn More",
#                               "target_url": "/rental-manager/resources/"
#                             }
#                           }
#                         },
#                         "href": "/rental-manager/resources/",
#                         "id": "resource_center",
#                         "text": "Resource Center"
#                       },
#                       {
#                         "classString": "noroute",
#                         "gaClickEventObj": {
#                           "action": "click",
#                           "category": "manage_rentals",
#                           "label": "help",
#                           "newLaneEvent": {
#                             "clickstream_trigger": {
#                               "trigger_location_nm": "top_navigation",
#                               "trigger_object_nm": "no_trigger_object",
#                               "trigger_source_nm": "top_navigation",
#                               "trigger_type_nm": "interaction"
#                             },
#                             "envelope": {
#                               "event_client_start_dtm": "Sun Sep 24 2023",
#                               "event_template_id": "242",
#                               "event_template_version_id": "1",
#                               "event_type_id": 3781,
#                               "event_type_version_id": "1"
#                             },
#                             "semantic": {
#                               "semantic_event_nm": "top_nav_click"
#                             },
#                             "top_navigation": {
#                               "level_one_txt": "Manage Rentals",
#                               "level_three_txt": "Help Center",
#                               "level_two_txt": "Learn More",
#                               "target_url": "https://help.zillowrentalmanager.com/hc/en-us/"
#                             }
#                           }
#                         },
#                         "href": "https://help.zillowrentalmanager.com/hc/en-us/",
#                         "id": "help_center",
#                         "text": "Help Center"
#                       }
#                     ]
#                   ],
#                   "title": "Learn More"
#                 }
#               ]
#             },
#             {
#               "gaExpandoClickObj": {
#                 "action": "click_down",
#                 "category": "nav_menu",
#                 "label": "advertise"
#               },
#               "gaHoverEventObj": {
#                 "action": "mouseover",
#                 "category": "nav_menu",
#                 "label": "advertise",
#                 "newLaneEvent": {
#                   "clickstream_trigger": {
#                     "trigger_location_nm": "top_navigation",
#                     "trigger_object_nm": "no_trigger_object",
#                     "trigger_source_nm": "top_navigation",
#                     "trigger_type_nm": "interaction"
#                   },
#                   "envelope": {
#                     "event_client_start_dtm": "Sun Sep 24 2023",
#                     "event_template_id": "242",
#                     "event_template_version_id": "1",
#                     "event_type_id": 3784,
#                     "event_type_version_id": "1"
#                   },
#                   "semantic": {
#                     "semantic_event_nm": "top_nav_hover"
#                   },
#                   "top_navigation": {
#                     "level_one_txt": "Advertise",
#                     "level_three_txt": null,
#                     "level_two_txt": null,
#                     "target_url": "/z/partners/advertise/"
#                   }
#                 }
#               },
#               "link": {
#                 "href": "/z/partners/advertise/",
#                 "text": "Advertise"
#               }
#             }
#           ]
#         },
#         "regLogin": {
#           "sections": [
#             {
#               "link": {
#                 "href": "/user/acct/login/?cid=pf",
#                 "text": "Sign in"
#               }
#             },
#             {
#               "link": {
#                 "href": "/user/acct/register/?cid=pf",
#                 "text": "Join"
#               }
#             }
#           ]
#         }
#       }
#     }
#   },
#   "tourEligibility": {
#     "isPropertyTourEligible": false
#   },
#   "tourPhotos": [
#     {
#       "url": "https://maps.googleapis.com/maps/api/streetview?location=17+Carriage+Dr%2C+Irvine%2C+CA+92602&size=400x300&key=AIzaSyARFMLB1na-BBWf7_R3-5YOQQaHqEJf6RQ&source=outdoor&&signature=tln-ZFQAw23e8tGUMKxqvs1rj4Y="
#     }
#   ],
#   "tourViewCount": 0,
#   "unassistedShowing": null,
#   "virtualTourUrl": null,
#   "vrModel": {
#     "cdnHost": null,
#     "revisionId": null,
#     "vrModelGuid": null
#   },
#   "whatILove": null,
#   "yearBuilt": 1999,
#   "zestimate": 1542100,
#   "zestimateDeepDiveData": {
#     "zmaModel": null
#   },
#   "zestimateHighPercent": "6",
#   "zestimateLowPercent": "6",
#   "zillowOfferMarket": null,
#   "zipPlusFour": "0776",
#   "zipcode": "92602",
#   "zipcodeSearchUrl": {
#     "path": "/irvine-ca-92602/"
#   },
#   "zoContactSubtitle": null,
#   "zoMarketName": null,
#   "zoResaleStartAnOfferEnabled": null,
#   "zpid": 25521141
# }
