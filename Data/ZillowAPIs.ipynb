# %% [markdown]
# https://rapidapi.com/s.mahmoud97/api/zillow56
#
# I've signed up with this service for a free plan which allows 30 API calls a month. They did not ask for my credit card.
#
# Please test it out to see if this would work for our purpose. If yes, we will try to secure fund to buy a paid plan. Thanks!

# %%
#27 Winterfield Rd

import http.client

conn = http.client.HTTPSConnection("zillow56.p.rapidapi.com")

headers = {
    'X-RapidAPI-Key': "7a19687cdfmshbcf34fbdd6d1f3bp16b9b2jsna3aeadf4281a",
    'X-RapidAPI-Host': "zillow56.p.rapidapi.com"
}

conn.request("GET", "/search_address?address=27%20Winterfield%20Rd%20Irvine%20CA%2092602", headers=headers)
res = conn.getresponse()
data = res.read()

print(data.decode("utf-8"))
# Out:
# {
#   "abbreviatedAddress": "27 Winterfield Rd",
#   "address": {
#     "city": "Irvine",
#     "community": null,
#     "neighborhood": null,
#     "state": "CA",
#     "streetAddress": "27 Winterfield Rd",
#     "subdivision": null,
#     "zipcode": "92602"
#   },
#   "apartmentsForRentInZipcodeSearchUrl": {
#     "path": "/irvine-ca-92602/apartments/"
#   },
#   "attributionInfo": {
#     "agentEmail": null,
#     "agentLicenseNumber": "DRE #02008739",
#     "agentName": "Anthony Mangahis Labao",
#     "agentPhoneNumber": null,
#     "attributionTitle": "Listing Provided by:",
#     "brokerName": "Lou Edwards Financial",
#     "brokerPhoneNumber": "949-870-2882",
#     "buyerAgentMemberStateLicense": null,
#     "buyerAgentName": null,
#     "buyerBrokerageName": null,
#     "coAgentLicenseNumber": "DRE #02154371",
#     "coAgentName": "LOU WU",
#     "coAgentNumber": "949-870-2882",
#     "infoList1": [
#       {
#         "infoField1": "listOffice",
# ...
