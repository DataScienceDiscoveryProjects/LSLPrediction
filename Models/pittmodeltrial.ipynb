# %%
import mlflow
from mlflow.models import infer_signature

import pandas as pd
from sklearn import datasets
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# %%
pd.read_csv("pittsburgh_normalized.csv")
# Out:
#         abbreviatedAddress  bathrooms  bedrooms        city   cityId  \
# 0          4221 Sherrod St        3.0       3.0  Pittsburgh  26529.0
# 1      5433 McCandless Ave        1.0       2.0  Pittsburgh  26529.0
# 2          30 Fairfield Ct        4.0       4.0  Pittsburgh  26529.0
# 3            3803 Penn Ave        1.0       3.0  Pittsburgh  26529.0
# 4            4236 Bruce St        2.0       2.0  Pittsburgh  26529.0
# ...                    ...        ...       ...         ...      ...
# 20049           121 6th St        2.0       3.0  Pittsburgh  26529.0
# 20050       414 William St        NaN       NaN  Pittsburgh  26529.0
# 20051        119 Bronx Ave        2.0       2.0  Pittsburgh  26529.0
# 20052          Lincoln Ave        NaN       NaN  Pittsburgh  26529.0
# 20053        901 Ridge Ave        1.0       2.0  Pittsburgh  23131.0
#
#                  county  countyFIPS  countyId           homeType  \
# 0      Allegheny County     42003.0    2614.0      SINGLE_FAMILY
# 1      Allegheny County     42003.0    2614.0      SINGLE_FAMILY
# 2      Allegheny County     42003.0    2614.0      SINGLE_FAMILY
# 3      Allegheny County     42003.0    2614.0      SINGLE_FAMILY
# 4      Allegheny County     42003.0    2614.0      SINGLE_FAMILY
# ...                 ...         ...       ...                ...
# 20049  Allegheny County     42003.0    2614.0      SINGLE_FAMILY
# 20050  Allegheny County         NaN    2614.0  HOME_TYPE_UNKNOWN
# 20051  Allegheny County     42003.0    2614.0      SINGLE_FAMILY
# 20052  Allegheny County     42003.0    2614.0  HOME_TYPE_UNKNOWN
# 20053  Allegheny County     42003.0    2614.0  HOME_TYPE_UNKNOWN
#
#        lastSoldPrice  ...  American Indian and Alaska Native alone  \
# 0           537500.0  ...                                 0.000000
# 1            26300.0  ...                                 0.000000
# 2           286500.0  ...                                 0.000000
# 3           299900.0  ...                                 0.000000
# 4           168000.0  ...                                 0.000000
# ...              ...  ...                                      ...
# 20049       208955.0  ...                                 0.000930
# 20050            NaN  ...                                 0.000930
# 20051       125000.0  ...                                 0.000930
# 20052            NaN  ...                                 0.000000
# 20053        35000.0  ...                                 0.000825
#
#        Native Hawaiian and Other Pacific Islander alone  \
# 0                                              0.000000
# 1                                              0.000000
# 2                                              0.000000
# 3                                              0.000000
# 4                                              0.000000
# ...                                                 ...
# 20049                                          0.000000
# 20050                                          0.000000
# 20051                                          0.000000
# 20052                                          0.012653
# 20053                                          0.000000
#
#        Some Other Race alone  Population 18 to 24 years  \
# 0                   0.008629                   0.035207
# 1                   0.008629                   0.035207
# 2                   0.008629                   0.035207
# 3                   0.008629                   0.035207
# 4                   0.008629                   0.035207
# ...                      ...                        ...
# 20049               0.004743                   0.034623
# 20050               0.004743                   0.034623
# 20051               0.004743                   0.034623
# 20052               0.005624                   0.048538
# 20053               0.018331                   0.048248
#
#        Population 25 years and over  Population 25 to 34 years  \
# 0                          0.482397                   0.191741
# 1                          0.482397                   0.191741
# 2                          0.482397                   0.191741
# 3                          0.482397                   0.191741
# 4                          0.482397                   0.191741
# ...                             ...                        ...
# 20049                      0.482688                   0.107304
# 20050                      0.482688                   0.107304
# 20051                      0.482688                   0.107304
# 20052                      0.475731                   0.127530
# 20053                      0.475876                   0.102528
#
#       Population 35 to 44 years  Population 45 to 64 years  \
# 0                      0.080473                   0.126313
# 1                      0.080473                   0.126313
# 2                      0.080473                   0.126313
# 3                      0.080473                   0.126313
# 4                      0.080473                   0.126313
# ...                         ...                        ...
# 20049                  0.102875                   0.155352
# 20050                  0.102875                   0.155352
# 20051                  0.102875                   0.155352
# 20052                  0.047414                   0.181878
# 20053                  0.071160                   0.187205
#
#        Population 65 years and over Income normalized
# 0                          0.083870        536.945032
# 1                          0.083870        536.945032
# 2                          0.083870        536.945032
# 3                          0.083870        536.945032
# 4                          0.083870        536.945032
# ...                             ...               ...
# 20049                      0.117158        487.589852
# 20050                      0.117158        487.589852
# 20051                      0.117158        487.589852
# 20052                      0.118909        379.598309
# 20053                      0.114984        474.302326
#
# [20054 rows x 43 columns]
